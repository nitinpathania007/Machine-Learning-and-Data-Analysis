# %%
import psycopg2
import pandas

# %%
conn = psycopg2.connect(user='new_haven_ds_read', 
                        password='new_haven_ds_secret_99',
                        host='nhds.c7jjptl82bki.us-east-2.rds.amazonaws.com',
                        database='nhds')

# %%
sql = 'select * from nhds.uci_adults'

# %%
cursor = conn.cursor()

# %%
cursor.execute(sql)

# %%
res = cursor.fetchall()

# %%
len(res)
# Out:
# 32561

# %%
df = pandas.DataFrame(res)
df.tail()
# Out:
#            0   1              2       3            4   5                    6  \
# 32556  32557  27        Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  32558  40        Private  154374      HS-grad   9   Married-civ-spouse
# 32558  32559  58        Private  151910      HS-grad   9              Widowed
# 32559  32560  22        Private  201490      HS-grad   9        Never-married
# 32560  32561  52   Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
#                         7           8       9       10     11  12  13  \
# 32556        Tech-support        Wife   White   Female      0   0  38
# 32557   Machine-op-inspct     Husband   White     Male      0   0  40
# 32558        Adm-clerical   Unmarried   White   Female      0   0  40
# 32559        Adm-clerical   Own-child   White     Male      0   0  20
# 32560     Exec-managerial        Wife   White   Female  15024   0  40
#
#                    14      15
# 32556   United-States   <=50K
# 32557   United-States    >50K
# 32558   United-States   <=50K
# 32559   United-States   <=50K
# 32560   United-States    >50K

# %%
df.to_pickle('df.pkl')

# %%
del(df)

# %%
df = pandas.read_pickle('df.pkl')

# %%
df.tail()
# Out:
#            0   1              2       3            4   5                    6  \
# 32556  32557  27        Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  32558  40        Private  154374      HS-grad   9   Married-civ-spouse
# 32558  32559  58        Private  151910      HS-grad   9              Widowed
# 32559  32560  22        Private  201490      HS-grad   9        Never-married
# 32560  32561  52   Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
#                         7           8       9       10     11  12  13  \
# 32556        Tech-support        Wife   White   Female      0   0  38
# 32557   Machine-op-inspct     Husband   White     Male      0   0  40
# 32558        Adm-clerical   Unmarried   White   Female      0   0  40
# 32559        Adm-clerical   Own-child   White     Male      0   0  20
# 32560     Exec-managerial        Wife   White   Female  15024   0  40
#
#                    14      15
# 32556   United-States   <=50K
# 32557   United-States    >50K
# 32558   United-States   <=50K
# 32559   United-States   <=50K
# 32560   United-States    >50K
